# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv("college_1.csv")
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2 = pd.read_csv("college_2.csv")
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df = df2.append(df1, ignore_index = True)
df
# Out:
#                   Name  python  python_en  mysql  computational_thinking  \
# 0        ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1              Chandru     0.0       20.0    0.0                     0.0
# 2    Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 3      Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 4            VIINU V P    -1.0      100.0   24.0                    -1.0
# ..                 ...     ...        ...    ...                     ...
# 114       KarthikeyanS    45.0        NaN    0.0                     NaN
# 115           BARATH.P    29.0        NaN    0.0                     NaN
# 116      N.Ajith kumar    82.0        NaN    0.0                     NaN
# 117       mohamed nabi     0.0        NaN    0.0                     NaN
# 118     yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#      Previous Geekions  CodeKata Score  \
# 0                19400           19400
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Exceeded_Expectations = df[df['CodeKata Score']>=15000]
Exceeded_Expectations
# Out:
#              Name  python  python_en  mysql  computational_thinking  \
# 0   ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 35      A.Dharani    82.0        NaN   20.0                     NaN
# 36    V.JEEVITHA     82.0        NaN   20.0                     NaN
# 37    HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#     Previous Geekions  CodeKata Score                              Department  \
# 0               19400           19400  Electronics and Electrical Engineering
# 35              24500           24500        Computer Science and Engineering
# 36              21740           21740        Computer Science and Engineering
# 37              19680           19680        Computer Science and Engineering
#
#     Rising
# 0        0
# 35       0
# 36       0
# 37       0

# %%
Exceeded_Expectations.to_csv('Exceeded_expectations.csv', index=False)

# %%
Exceeded_Expectation_csv = pd.read_csv("Exceeded_expectations.csv")
Exceeded_Expectation_csv
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1      A.Dharani    82.0        NaN   20.0                     NaN
# 2    V.JEEVITHA     82.0        NaN   20.0                     NaN
# 3    HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
# 1              24500           24500        Computer Science and Engineering
# 2              21740           21740        Computer Science and Engineering
# 3              19680           19680        Computer Science and Engineering
#
#    Rising
# 0       0
# 1       0
# 2       0
# 3       0

# %%
Reached_Expectations = df[df['CodeKata Score'].between(10000,15000)]
Reached_Expectations
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 1             Chandru     0.0       20.0    0.0                     0.0
# 2   Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 3     Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 38        Mugunthan S   100.0        NaN   47.0                     NaN
#
#     Previous Geekions  CodeKata Score  \
# 1               14150           14490
# 2                8790           10790
# 3               10040           10040
# 38              10610           10610
#
#                                    Department  Rising
# 1            Computer Science and Engineering     340
# 2            Computer Science and Engineering    2000
# 3   Electronics and Communication Engineering       0
# 38           Computer Science and Engineering       0

# %%
Reached_Expectations.to_csv('Reached_expectations.csv', index=False)

# %%
Reached_Expectation_csv = pd.read_csv("Reached_expectations.csv")
Reached_Expectation_csv
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0            Chandru     0.0       20.0    0.0                     0.0
# 1  Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 2    Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 3        Mugunthan S   100.0        NaN   47.0                     NaN
#
#    Previous Geekions  CodeKata Score  \
# 0              14150           14490
# 1               8790           10790
# 2              10040           10040
# 3              10610           10610
#
#                                   Department  Rising
# 0           Computer Science and Engineering     340
# 1           Computer Science and Engineering    2000
# 2  Electronics and Communication Engineering       0
# 3           Computer Science and Engineering       0

# %%
Needs_improvement = df[df['CodeKata Score'].between(7000,10000)]
Needs_improvement
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 4                VIINU V P    -1.0      100.0   24.0                    -1.0
# 5               Poojitha Y     0.0       78.0   35.0                     0.0
# 6   Gowtham Chandrasekaran    -1.0        0.0    0.0                     3.0
# 7                Gowtham R    -1.0       60.0    4.0                     6.0
# 8                 shifak N    58.0        0.0    0.0                     0.0
# 9                  Balaji     -1.0      100.0   20.0                     0.0
# 10                Rushitha    -1.0       15.0   62.0                     9.0
# 11    Balaraman Muthupandi    -1.0        9.0    0.0                     0.0
# 12                JPradhap   100.0        0.0    0.0                     0.0
# 13           SRIRAMKUMAR B    -1.0        0.0    0.0                     0.0
# 14               Praneetha    -1.0       23.0  100.0                    -1.0
# ...

# %%
Needs_improvement.to_csv('Needs_Improvement.csv', index=False)

# %%
Needs_Improvement_csv = pd.read_csv("Needs_Improvement.csv")
Needs_Improvement_csv
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0                VIINU V P    -1.0      100.0   24.0                    -1.0
# 1               Poojitha Y     0.0       78.0   35.0                     0.0
# 2   Gowtham Chandrasekaran    -1.0        0.0    0.0                     3.0
# 3                Gowtham R    -1.0       60.0    4.0                     6.0
# 4                 shifak N    58.0        0.0    0.0                     0.0
# 5                  Balaji     -1.0      100.0   20.0                     0.0
# 6                 Rushitha    -1.0       15.0   62.0                     9.0
# 7     Balaraman Muthupandi    -1.0        9.0    0.0                     0.0
# 8                 JPradhap   100.0        0.0    0.0                     0.0
# 9            SRIRAMKUMAR B    -1.0        0.0    0.0                     0.0
# 10               Praneetha    -1.0       23.0  100.0                    -1.0
# ...

# %%
UnSatisfactory = df[df['CodeKata Score']<7000]
UnSatisfactory
# Out:
#                Name  python  python_en  mysql  computational_thinking  \
# 18   Narasimhan Y L    -1.0       -1.0    0.0                     0.0
# 19     Leelakrishna    -1.0        6.0    4.0                     0.0
# 20   PremsagarReddy    -1.0       20.0    0.0                     0.0
# 21        pradeeban    16.0       20.0   24.0                     0.0
# 22      santhoshini    -1.0       43.0    0.0                     0.0
# ..              ...     ...        ...    ...                     ...
# 114    KarthikeyanS    45.0        NaN    0.0                     NaN
# 115        BARATH.P    29.0        NaN    0.0                     NaN
# 116   N.Ajith kumar    82.0        NaN    0.0                     NaN
# 117    mohamed nabi     0.0        NaN    0.0                     NaN
# 118  yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#      Previous Geekions  CodeKata Score  \
# 18                4800            6800
# 19                5300            6640
# ...

# %%
UnSatisfactory.to_csv('Unsatisfactory.csv', index=False)

# %%
Unsatisfactory_csv = pd.read_csv("Unsatisfactory.csv")
Unsatisfactory_csv
# Out:
#               Name  python  python_en  mysql  computational_thinking  \
# 0   Narasimhan Y L    -1.0       -1.0    0.0                     0.0
# 1     Leelakrishna    -1.0        6.0    4.0                     0.0
# 2   PremsagarReddy    -1.0       20.0    0.0                     0.0
# 3        pradeeban    16.0       20.0   24.0                     0.0
# 4      santhoshini    -1.0       43.0    0.0                     0.0
# ..             ...     ...        ...    ...                     ...
# 88    KarthikeyanS    45.0        NaN    0.0                     NaN
# 89        BARATH.P    29.0        NaN    0.0                     NaN
# 90   N.Ajith kumar    82.0        NaN    0.0                     NaN
# 91    mohamed nabi     0.0        NaN    0.0                     NaN
# 92  yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#     Previous Geekions  CodeKata Score                              Department  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df[['Previous Geekions','CodeKata Score']].mean()
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
No_of_Students_Participated = df['Name'].nunique()
No_of_Students_Participated
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
Python = df[df['python']==100]
Python
# Out:
#                            Name  python  python_en   mysql  \
# 0                 ASHOK KUMAR K   100.0        0.0   31.00
# 12                     JPradhap   100.0        0.0    0.00
# 37                  HEMAVATHI.R   100.0        NaN  100.00
# 38                  Mugunthan S   100.0        NaN   47.00
# 39                  Sathammai.S   100.0        NaN    8.00
# 40                 NIVEESHWAR S   100.0        NaN    0.00
# 46                 Ponniyamma.R   100.0        NaN   11.25
# 47                    SABAPATHI   100.0        NaN    0.00
# 48                     RAGHAVAN   100.0        NaN    0.00
# 50                     Pavithra   100.0        NaN  100.00
# 52                  v.vithyasri   100.0        NaN   12.00
# 53           Abirami Anbazhagan   100.0        NaN    0.00
# 54                 S.srinivasan   100.0        NaN   12.00
# 55                     s.janani   100.0        NaN    0.00
# 57                      Yuvasri   100.0        NaN  100.00
# ...

# %%
Mysql = df[df['mysql']==100]
Mysql
# Out:
#               Name  python  python_en  mysql  computational_thinking  \
# 14       Praneetha    -1.0       23.0  100.0                    -1.0
# 37     HEMAVATHI.R   100.0        NaN  100.0                     NaN
# 50        Pavithra   100.0        NaN  100.0                     NaN
# 57         Yuvasri   100.0        NaN  100.0                     NaN
# 59         MEERA.M   100.0        NaN  100.0                     NaN
# 61   sri dharshini   100.0        NaN  100.0                     NaN
# 63   pooja priya.B   100.0        NaN  100.0                     NaN
# 69      tamilarasi   100.0        NaN  100.0                     NaN
# 79         ponni.p    93.0        NaN  100.0                     NaN
# 80      PRAVEENA K   100.0        NaN  100.0                     NaN
# 84        bavithra     0.0        NaN  100.0                     NaN
# 91         pravina   100.0        NaN  100.0                     NaN
# 99      k.parvathi   100.0        NaN  100.0                     NaN
# ...

# %%
Computational_Thinking = df[df['computational_thinking']==100]
Computational_Thinking
# Out:
# Empty DataFrame
# Columns: [Name, python, python_en, mysql, computational_thinking, Previous Geekions, CodeKata Score, Department, Rising]
# Index: []

# %%
Python_English = df[df['python_en']==100]
Python_English
# Out:
#         Name  python  python_en  mysql  computational_thinking  \
# 4  VIINU V P    -1.0      100.0   24.0                    -1.0
# 9    Balaji     -1.0      100.0   20.0                     0.0
#
#    Previous Geekions  CodeKata Score                              Department  \
# 4               9150            9150  Electronics and Electrical Engineering
# 9               6170            8160  Electronics and Electrical Engineering
#
#    Rising
# 4       0
# 9    1990

# %%
Python.shape
# Out:
# (41, 9)

# %%
Python_Total = Python.shape[0]
Python_Total
# Out:
# 41

# %%
Mysql.shape
# Out:
# (14, 9)

# %%
Mysql_Total = Mysql.shape[0]
Mysql_Total
# Out:
# 14

# %%
Computational_Thinking.shape
# Out:
# (0, 9)

# %%
Computational_Thinking_Total = Computational_Thinking.shape[0]
Computational_Thinking_Total
# Out:
# 0

# %%
Python_English.shape
# Out:
# (2, 9)

# %%
Python_English_Total = Python_English.shape[0]
Python_English_Total
# Out:
# 2

# %%
Total_Completion = (Python_Total + Mysql_Total + Computational_Thinking_Total + Python_English_Total)
Total_Completion
# Out:
# 57

# %%
Avg_Completion = Total_Completion/4
Avg_Completion
# Out:
# 14.25

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
index = [1,2,3]
Rising_Star = df.sort_values('Rising',ascending=False,).head(3).reset_index()
Rising_Star
# Out:
#    index               Name  python  python_en  mysql  computational_thinking  \
# 0      8           shifak N    58.0        0.0    0.0                     0.0
# 1      2  Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 2     18     Narasimhan Y L    -1.0       -1.0    0.0                     0.0
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0               5180            8320  Electronics and Electrical Engineering
# 1               8790           10790        Computer Science and Engineering
# 2               4800            6800        Computer Science and Engineering
#
#    Rising
# 0    3140
# 1    2000
# 2    2000

# %%
Rising_Stars = Rising_Star['Name']
Rising_Stars
# Out:
# 0             shifak N
# 1    Ganesh Ramkumar R
# 2       Narasimhan Y L
# Name: Name, dtype: object

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
Shining_Star_Geekions = df.sort_values('Previous Geekions',ascending=False).head(3).reset_index()
Shining_Star_Geekions
# Out:
#    index         Name  python  python_en  mysql  computational_thinking  \
# 0     35    A.Dharani    82.0        NaN   20.0                     NaN
# 1     36  V.JEEVITHA     82.0        NaN   20.0                     NaN
# 2     37  HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#    Previous Geekions  CodeKata Score                        Department  Rising
# 0              24500           24500  Computer Science and Engineering       0
# 1              21740           21740  Computer Science and Engineering       0
# 2              19680           19680  Computer Science and Engineering       0

# %%
Shining_Stars_Geekions = Shining_Star_Geekions['Name']
Shining_Stars_Geekions
# Out:
# 0      A.Dharani
# 1    V.JEEVITHA
# 2    HEMAVATHI.R
# Name: Name, dtype: object

# %%
Shining_Stars_Geekions =list(Shining_Star_Geekions['Name'])
Shining_Stars_Geekions
# Out:
# ['A.Dharani', 'V.JEEVITHA ', 'HEMAVATHI.R']

# %%
Shining_Star_Codekata = df.sort_values('CodeKata Score',ascending=False).head(3).reset_index()
Shining_Star_Codekata
# Out:
#    index         Name  python  python_en  mysql  computational_thinking  \
# 0     35    A.Dharani    82.0        NaN   20.0                     NaN
# 1     36  V.JEEVITHA     82.0        NaN   20.0                     NaN
# 2     37  HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#    Previous Geekions  CodeKata Score                        Department  Rising
# 0              24500           24500  Computer Science and Engineering       0
# 1              21740           21740  Computer Science and Engineering       0
# 2              19680           19680  Computer Science and Engineering       0

# %%
Shining_Stars_Codekata = Shining_Star_Codekata['Name']
Shining_Stars_Codekata
# Out:
# 0      A.Dharani
# 1    V.JEEVITHA
# 2    HEMAVATHI.R
# Name: Name, dtype: object

# %%
Shining_Stars_Codekata =list(Shining_Star_Codekata['Name'])
Shining_Stars_Codekata
# Out:
# ['A.Dharani', 'V.JEEVITHA ', 'HEMAVATHI.R']

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
Dept_Codekata_Perf = df.groupby('Department').sum()
Dept_Codekata_Perf
# Out:
#                                            python  python_en    mysql  \
# Department
# Computer Science and Engineering           3844.0      487.0  1397.25
# Electronics and Communication Engineering  1532.5      351.0  1057.25
# Electronics and Electrical Engineering     1091.5      200.0   342.00
#
#                                            computational_thinking  \
# Department
# Computer Science and Engineering                             23.0
# Electronics and Communication Engineering                    46.0
# Electronics and Electrical Engineering                        8.0
#
#                                            Previous Geekions  CodeKata Score  \
# Department
# Computer Science and Engineering                      301935          320025
# Electronics and Communication Engineering             107325          108335
# Electronics and Electrical Engineering                 47980           53800
#
#                                            Rising
# Department
# ...

# %%
Codekata_Perf = list(Dept_Codekata_Perf['CodeKata Score'])
Codekata_Perf
# Out:
# [320025, 108335, 53800]

# %%
Departments = list(Dept_Codekata_Perf.index)
Departments
# Out:
# ['Computer Science and Engineering',
#  'Electronics and Communication Engineering',
#  'Electronics and Electrical Engineering']

# %%
values = Codekata_Perf
labels = Departments
plt.figure(figsize=(6,10))
textprops = {"fontsize":15}
plt.pie(values,shadow = True,labels = labels,colors = ["blue","red","yellow"],autopct = "%2.2f%%",textprops =textprops)
plt.title("Dept_Wise Codekata Performance Piechart",fontsize = 25)
plt.legend(title = "Departments",loc=3, bbox_to_anchor=(1,0.5,1,1),fontsize=12)
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
Toppers = df.groupby(['Department']).apply(lambda gdf:gdf.assign(Max_Score=lambda df: df['CodeKata Score'].max()))
Toppers
# Out:
#                                                               Name  python  \
# Department
# Computer Science and Engineering       1                   Chandru     0.0
#                                        2         Ganesh Ramkumar R    -1.0
#                                        5                Poojitha Y     0.0
#                                        6    Gowtham Chandrasekaran    -1.0
#                                        10                 Rushitha    -1.0
# ...                                                            ...     ...
# Electronics and Electrical Engineering 114            KarthikeyanS    45.0
#                                        115                BARATH.P    29.0
#                                        116           N.Ajith kumar    82.0
#                                        117            mohamed nabi     0.0
#                                        118          yaser ahamed.A     0.0
#
# ...

# %%
Dept_Toppers = Toppers.loc[Toppers['CodeKata Score'] == Toppers['Max_Score']]
Dept_Toppers
# Out:
#                                                          Name  python  \
# Department
# Computer Science and Engineering          35        A.Dharani    82.0
# Electronics and Communication Engineering 3   Bodipudi Harini    -1.0
# Electronics and Electrical Engineering    0     ASHOK KUMAR K   100.0
#
#                                               python_en  mysql  \
# Department
# Computer Science and Engineering          35        NaN   20.0
# Electronics and Communication Engineering 3         0.0   35.0
# Electronics and Electrical Engineering    0         0.0   31.0
#
#                                               computational_thinking  \
# Department
# Computer Science and Engineering          35                     NaN
# Electronics and Communication Engineering 3                     -1.0
# Electronics and Electrical Engineering    0                      9.0
#
#                                               Previous Geekions  \
# Department
# ...

# %%
x = list(Dept_Toppers['Department'])
x
# Out:
# ['Computer Science and Engineering',
#  'Electronics and Communication Engineering',
#  'Electronics and Electrical Engineering']

# %%
y = list(Dept_Toppers['CodeKata Score'])
y
# Out:
# [24500, 10040, 19400]

# %%
data = list(Dept_Toppers['Name'])
data
# Out:
# ['A.Dharani', 'Bodipudi Harini', 'ASHOK KUMAR K']

# %%
plt.barh(x,y, height = 0.5, color = ['green','red','brown'],edgecolor = 'black')
plt.xlabel("Codekata_Score")
plt.ylabel("Departments")
plt.title("Department Wise Toppers")
for index, value in enumerate(x):
  plt.text(index+y[index],value,data[index])
